# %% [markdown]
# # ECE9039 MACHINE LEARNING

# %% [markdown]
# ## Data Preprocessing

# %%
import tensorflow as tf
import numpy as np
import os
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization, Activation, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from collections import Counter
from sklearn.utils import shuffle
from PIL import Image, ImageOps
from sklearn.metrics import accuracy_score
import random
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler
from tensorflow.keras.models import load_model
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import cross_val_score

# %%
gpus = tf.config.list_physical_devices('GPU')

if gpus:
    print(f"Num GPUs Available: {len(gpus)}")
    for gpu in gpus:
        print("Name:", gpu.name, "Type:", gpu.device_type)
else:
    print("No GPU is available.")
# Out:
# Num GPUs Available: 1
# Name: /physical_device:GPU:0 Type: GPU

# %% [markdown]
# ### Load dataset

# %%
def load_images_and_labels(dataset_path, target_size=(224, 224)):
    images = []
    labels = []
    
    # Loop through each subfolder in the dataset directory
    for root, dirs, files in os.walk(dataset_path):
        if root == dataset_path:
            continue
        label = os.path.basename(root)
        count = 0
        for file in sorted(files):
            if file.lower().endswith(".jpg"):
                # Construct the full path to the image file
                file_path = os.path.join(root, file)
                image = Image.open(file_path).convert('RGB').resize(target_size)
                images.append(np.array(image))
                labels.append(label)
                count += 1
                
    return np.array(images), np.array(labels)

# %%
dataset_path = 'RealWaste/'
images, labels = load_images_and_labels(dataset_path)

print("Images shape:", images.shape)
print("Labels count:", len(np.unique(labels)))
# Out:
# Images shape: (4752, 224, 224, 3)
# Labels count: 9

# %%
indices = np.arange(images.shape[0])
np.random.shuffle(indices)
images = images[indices]
labels = labels[indices]

# %%
label_counts = Counter(labels)
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# Textile Trash: 318
# Metal: 790
# Cardboard: 461
# Paper: 500
# Miscellaneous Trash: 495
# Vegetation: 436
# Plastic: 921
# Glass: 420
# Food Organics: 411

# %% [markdown]
# ### Isolate test set

# %%
num_of_test_samples_per_class = 100
target_num_of_train_per_class = 800

# %%
classes = np.unique(labels)
test_indices = []
train_indices = []

for class_label in classes:
    # Find the indices of images belonging to the current class
    class_indices = np.where(labels == class_label)[0]
    
    # Shuffle the indices to ensure random selection
    np.random.shuffle(class_indices)
    test_indices.extend(class_indices[:num_of_test_samples_per_class])
    train_indices.extend(class_indices[num_of_test_samples_per_class:])

test_images = images[test_indices]
test_labels = labels[test_indices]
train_images = images[train_indices]
train_labels = labels[train_indices]

# %%
print(train_images.shape)
print(train_labels.shape)
# Out:
# (3852, 224, 224, 3)
# (3852,)

# %%
del images
del labels

# %%
label_counts = Counter(train_labels)
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# Cardboard: 361
# Food Organics: 311
# Glass: 320
# Metal: 690
# Miscellaneous Trash: 395
# Paper: 400
# Plastic: 821
# Textile Trash: 218
# Vegetation: 336

# %% [markdown]
# ### Data augmentation

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
dict = {}
for i in label_counts:
    desired = target_num_of_train_per_class-label_counts[i]
    dict[i] = desired if desired > 0 else 0

# %%
print(dict)
print(sum(dict.values()))
# Out:
# {'Cardboard': 439, 'Food Organics': 489, 'Glass': 480, 'Metal': 110, 'Miscellaneous Trash': 405, 'Paper': 400, 'Plastic': 0, 'Textile Trash': 582, 'Vegetation': 464}
# 3369

# %%
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.1,
    height_shift_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
augmented_images = []
augmented_labels = []

def generate_augmented_image(image, label): #,index
    for x_batch in datagen.flow(image.reshape((1,)+image.shape),batch_size=1): # ,save_to_dir='Preview', save_prefix=str(index), save_format='jpg'
        augmented_images.append(x_batch[0])
        augmented_labels.append(label)
        break

# %%
i = 0
while sum(dict.values()) > 0:
    j = i % len(train_images)
    if dict[train_labels[j]] > 0:
        dict[train_labels[j]]-=1 
        generate_augmented_image(train_images[j],train_labels[j])
    i+=1

# %%
print(np.array(augmented_images).shape)
print(np.array(augmented_labels).shape)
# Out:
# (3369, 224, 224, 3)
# (3369,)

# %%
train_aug_images = np.concatenate((train_images,augmented_images))
train_aug_labels = np.concatenate((train_labels,augmented_labels))

# %%
print(train_aug_images.shape)
print(train_aug_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (7221, 224, 224, 3)
# (7221,)
# (900, 224, 224, 3)
# (900,)

# %%
label_counts = Counter(train_aug_labels)
for label, count in label_counts.items():
    print(f"{label}: {count}")
# Out:
# Cardboard: 800
# Food Organics: 800
# Glass: 800
# Metal: 800
# Miscellaneous Trash: 800
# Paper: 800
# Plastic: 821
# Textile Trash: 800
# Vegetation: 800

# %%
label_encoder = LabelEncoder()
train_aug_labels_encoded = label_encoder.fit_transform(train_aug_labels)
test_labels_encoded = label_encoder.transform(test_labels)

# %%
label_mapping = {label: index for index, label in enumerate(label_encoder.classes_)}

#print("Encoded Labels for Training Data:", train_aug_labels_encoded)
#print("Encoded Labels for Test Data:", test_labels_encoded)
print("Label Mapping:", label_mapping)
# Out:
# Label Mapping: {'Cardboard': 0, 'Food Organics': 1, 'Glass': 2, 'Metal': 3, 'Miscellaneous Trash': 4, 'Paper': 5, 'Plastic': 6, 'Textile Trash': 7, 'Vegetation': 8}

# %%
index_to_label = {index: label for label, index in label_mapping.items()}

# %%
X_train = train_aug_images
y_train = train_aug_labels_encoded

X_val, X_test, y_val, y_test = train_test_split(test_images, test_labels_encoded, test_size=0.5, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X_val.shape)
print(y_val.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (7221, 224, 224, 3)
# (7221,)
# (450, 224, 224, 3)
# (450,)
# (450, 224, 224, 3)
# (450,)

# %%
del train_aug_images
del train_aug_labels
del train_aug_labels_encoded
#del test_images
del test_labels
#del test_labels_encoded

# %% [markdown]
# ## Feature Extraction Methods

# %% [markdown]
# ### SIFT

# %%
import cv2

# %%
def extract_sift_features(images, labels, num_strongest=100):
    sift = cv2.SIFT_create(num_strongest)
    features = []
    new_labels = []
    
    i = 0
    for i in range(len(images)):
        gray = cv2.cvtColor(images[i], cv2.COLOR_RGB2GRAY)
        pts, des = sift.detectAndCompute(gray, None)
        j = 0
        for j in range(num_strongest):
            new_labels.append(labels[i])
            if j < len(des):
                features.append(np.array(des[j]))
            else:
                features.append(np.zeros((128,)))
        
    return np.array(features),np.array(new_labels)

# %%
def extract_sift_features2(images):
    # Initialize SIFT detector and select strongest 50
    sift = cv2.SIFT_create(50)
    features = []
    
    for img in images:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        # Detect SIFT features and compute descriptors
        pts, des = sift.detectAndCompute(gray, None)
        if des is not None:
            # Simple feature aggregation by taking the mean
            des_mean = np.mean(des, axis=0)
        else:
            # If no features are found, use a zero vector
            des_mean = np.zeros((128,))
        features.append(des_mean)
        
    return np.array(features)

# %%
train_labels_encoded = label_encoder.fit_transform(train_labels)

# %%
del X_train
del y_train
del X_val
del y_val
del X_test
del y_test

# %%
#X_train_SIFT, y_train_SIFT = extract_sift_features(train_images, train_labels_encoded)
#test_features, test_featured_labels = extract_sift_features(test_images, test_labels_encoded)
#X_val_SIFT, X_test_SIFT, y_val_SIFT, y_test_SIFT = train_test_split(test_features, test_featured_labels, test_size=0.5, random_state=42)
#del test_features
#del test_featured_labels

# %%
X_train_SIFT = extract_sift_features2(train_images)
y_train_SIFT = train_labels_encoded
del train_labels_encoded
test_features = extract_sift_features2(test_images)
X_val_SIFT, X_test_SIFT, y_val_SIFT, y_test_SIFT = train_test_split(test_features, test_labels_encoded, test_size=0.5, random_state=42)

# %%
print(X_train_SIFT.shape)
print(y_train_SIFT.shape)
print(X_val_SIFT.shape)
print(y_val_SIFT.shape)
print(X_test_SIFT.shape)
print(y_test_SIFT.shape)
# Out:
# (3852, 128)
# (3852,)
# (450, 128)
# (450,)
# (450, 128)
# (450,)

# %% [markdown]
# ## Dimensionality Reduction Methods

# %% [markdown]
# ### PCA

# %% [markdown]
# scaler = StandardScaler()
# X_train_des = scaler.fit_transform(X_train_des)
# X_test_des = scaler.fit_transform(X_test_des)
#
# pca = PCA(n_components=64)
# X_train_des = pca.fit_transform(X_train_des)
# X_test_des = pca.fit_transform(X_test_des)

# %% [markdown]
# ## Models use feature descriptors

# %% [markdown]
# ### Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier
from hyperopt import hp, fmin, tpe, STATUS_OK, Trials
from ray import train
from ray.tune.schedulers import HyperBandScheduler
from ray import tune
from sklearn.ensemble import AdaBoostClassifier

# %%
def train_random_forest_SIFT(config):    
    model = RandomForestClassifier(
        n_estimators=config["n_estimators"],
        max_depth=config["max_depth"],
        min_samples_split=config["min_samples_split"],
        min_samples_leaf=config["min_samples_leaf"],
        max_features=config["max_features"]
    )
    model.fit(X_train_SIFT, y_train_SIFT)
    scores = cross_val_score(model, X_train_SIFT, y_train_SIFT, cv=5)  # Using 5-fold cross-validation
    mean_accuracy = scores.mean()
    preds = model.predict(X_val_SIFT)
    val_accuracy = accuracy_score(y_val_SIFT, preds)
    
    train.report({'accuracy': mean_accuracy,
                 'val_accuracy': val_accuracy})

# %%
config = {
    "n_estimators": tune.choice([50, 100, 200, 400, 600, 800, 1000, 1500, 2000]),
    "max_depth": tune.choice([5, 10, 20, 50, 100, 200, 300, 500]),
    "min_samples_split": tune.choice([2, 5, 10, 20, 30]),
    "min_samples_leaf": tune.choice([1, 2, 4]),
    "max_features": tune.choice(["auto", "sqrt", "log2"])
}

# %%
analysis_SIFT = tune.run(
    train_random_forest_SIFT,
    config=config,
    num_samples=50,
    resources_per_trial={"cpu": 8},
)
# Out:
# 2024-03-19 11:41:11,380	INFO worker.py:1642 -- Started a local Ray instance.
# 2024-03-19 11:41:13,914	INFO tune.py:229 -- Initializing Ray automatically. For cluster usage or custom Ray initialization, call `ray.init(...)` before `tune.run(...)`.
# 2024-03-19 11:41:13,916	INFO tune.py:646 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-03-19 12:12:31</td></tr>
# <tr><td>Running for: </td><td>00:31:16.54        </td></tr>
# <tr><td>Memory:      </td><td>14.6/31.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 8.0/16 CPUs, 0/1 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                          </th><th>status    </th><th>loc            </th><th style="text-align: right;">  max_depth</th><th>max_features  </th><th style="text-align: right;">  min_samples_leaf</th><th style="text-align: right;">  min_samples_split</th><th style="text-align: right;">  n_estimators</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  accuracy</th><th style="text-align: right;">  val_accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_random_forest_SIFT_1e1b2_00000</td><td>TERMINATED</td><td>127.0.0.1:32020</td><td style="text-align: right;">          5</td><td>log2          </td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 10</td><td style="text-align: right;">            50</td><td style="text-align: right;">     1</td><td style="text-align: right;">         1.89272</td><td style="text-align: right;">  0.341384</td><td style="text-align: right;">      0.257778</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00001</td><td>TERMINATED</td><td>127.0.0.1:36344</td><td style="text-align: right;">        100</td><td>auto          </td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 10</td><td style="text-align: right;">           100</td><td style="text-align: right;">     1</td><td style="text-align: right;">        10.8271 </td><td style="text-align: right;">  0.404729</td><td style="text-align: right;">      0.344444</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00002</td><td>TERMINATED</td><td>127.0.0.1:32020</td><td style="text-align: right;">        300</td><td>log2          </td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 30</td><td style="text-align: right;">          1000</td><td style="text-align: right;">     1</td><td style="text-align: right;">        62.8322 </td><td style="text-align: right;">  0.393047</td><td style="text-align: right;">      0.342222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00003</td><td>TERMINATED</td><td>127.0.0.1:36344</td><td style="text-align: right;">          5</td><td>sqrt          </td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 10</td><td style="text-align: right;">          2000</td><td style="text-align: right;">     1</td><td style="text-align: right;">       107.662  </td><td style="text-align: right;">  0.348653</td><td style="text-align: right;">      0.28    </td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00004</td><td>TERMINATED</td><td>127.0.0.1:32020</td><td style="text-align: right;">        200</td><td>auto          </td><td style="text-align: right;">                 2</td><td style="text-align: right;">                  2</td><td style="text-align: right;">          1500</td><td style="text-align: right;">     1</td><td style="text-align: right;">       177.98   </td><td style="text-align: right;">  0.413034</td><td style="text-align: right;">      0.36    </td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00005</td><td>TERMINATED</td><td>127.0.0.1:36344</td><td style="text-align: right;">          5</td><td>sqrt          </td><td style="text-align: right;">                 4</td><td style="text-align: right;">                  2</td><td style="text-align: right;">          1500</td><td style="text-align: right;">     1</td><td style="text-align: right;">        80.8598 </td><td style="text-align: right;">  0.349432</td><td style="text-align: right;">      0.273333</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00006</td><td>TERMINATED</td><td>127.0.0.1:36344</td><td style="text-align: right;">        300</td><td>auto          </td><td style="text-align: right;">                 1</td><td style="text-align: right;">                  5</td><td style="text-align: right;">           100</td><td style="text-align: right;">     1</td><td style="text-align: right;">        11.3535 </td><td style="text-align: right;">  0.403694</td><td style="text-align: right;">      0.371111</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00007</td><td>TERMINATED</td><td>127.0.0.1:36344</td><td style="text-align: right;">        200</td><td>sqrt          </td><td style="text-align: right;">                 4</td><td style="text-align: right;">                  5</td><td style="text-align: right;">           100</td><td style="text-align: right;">     1</td><td style="text-align: right;">         9.89759</td><td style="text-align: right;">  0.398499</td><td style="text-align: right;">      0.353333</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00008</td><td>TERMINATED</td><td>127.0.0.1:36344</td><td style="text-align: right;">        200</td><td>log2          </td><td style="text-align: right;">                 2</td><td style="text-align: right;">                 10</td><td style="text-align: right;">          1500</td><td style="text-align: right;">     1</td><td style="text-align: right;">       110.031  </td><td style="text-align: right;">  0.404209</td><td style="text-align: right;">      0.357778</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00009</td><td>TERMINATED</td><td>127.0.0.1:32020</td><td style="text-align: right;">          5</td><td>log2          </td><td style="text-align: right;">                 1</td><td style="text-align: right;">                  5</td><td style="text-align: right;">          1000</td><td style="text-align: right;">     1</td><td style="text-align: right;">        37.3172 </td><td style="text-align: right;">  0.34346 </td><td style="text-align: right;">      0.284444</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00010</td><td>TERMINATED</td><td>127.0.0.1:32020</td><td style="text-align: right;">        200</td><td>log2          </td><td style="text-align: right;">                 4</td><td style="text-align: right;">                 20</td><td style="text-align: right;">           800</td><td style="text-align: right;">     1</td><td style="text-align: right;">        50.0738 </td><td style="text-align: right;">  0.395381</td><td style="text-align: right;">      0.333333</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00011</td><td>TERMINATED</td><td>127.0.0.1:32020</td><td style="text-align: right;">         50</td><td>log2          </td><td style="text-align: right;">                 2</td><td style="text-align: right;">                 10</td><td style="text-align: right;">           600</td><td style="text-align: right;">     1</td><td style="text-align: right;">        42.4962 </td><td style="text-align: right;">  0.403949</td><td style="text-align: right;">      0.348889</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00012</td><td>TERMINATED</td><td>127.0.0.1:36344</td><td style="text-align: right;">        100</td><td>log2          </td><td style="text-align: right;">                 1</td><td style="text-align: right;">                 10</td><td style="text-align: right;">          2000</td><td style="text-align: right;">     1</td><td style="text-align: right;">       146.311  </td><td style="text-align: right;">  0.404727</td><td style="text-align: right;">      0.362222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00013</td>
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                          </th><th style="text-align: right;">  accuracy</th><th style="text-align: right;">  val_accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>train_random_forest_SIFT_1e1b2_00000</td><td style="text-align: right;">  0.341384</td><td style="text-align: right;">      0.257778</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00001</td><td style="text-align: right;">  0.404729</td><td style="text-align: right;">      0.344444</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00002</td><td style="text-align: right;">  0.393047</td><td style="text-align: right;">      0.342222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00003</td><td style="text-align: right;">  0.348653</td><td style="text-align: right;">      0.28    </td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00004</td><td style="text-align: right;">  0.413034</td><td style="text-align: right;">      0.36    </td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00005</td><td style="text-align: right;">  0.349432</td><td style="text-align: right;">      0.273333</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00006</td><td style="text-align: right;">  0.403694</td><td style="text-align: right;">      0.371111</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00007</td><td style="text-align: right;">  0.398499</td><td style="text-align: right;">      0.353333</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00008</td><td style="text-align: right;">  0.404209</td><td style="text-align: right;">      0.357778</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00009</td><td style="text-align: right;">  0.34346 </td><td style="text-align: right;">      0.284444</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00010</td><td style="text-align: right;">  0.395381</td><td style="text-align: right;">      0.333333</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00011</td><td style="text-align: right;">  0.403949</td><td style="text-align: right;">      0.348889</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00012</td><td style="text-align: right;">  0.404727</td><td style="text-align: right;">      0.362222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00013</td><td style="text-align: right;">  0.402391</td><td style="text-align: right;">      0.348889</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00014</td><td style="text-align: right;">  0.403173</td><td style="text-align: right;">      0.351111</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00015</td><td style="text-align: right;">  0.39097 </td><td style="text-align: right;">      0.331111</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00016</td><td style="text-align: right;">  0.393308</td><td style="text-align: right;">      0.34    </td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00017</td><td style="text-align: right;">  0.387854</td><td style="text-align: right;">      0.348889</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00018</td><td style="text-align: right;">  0.342161</td><td style="text-align: right;">      0.291111</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00019</td><td style="text-align: right;">  0.410701</td><td style="text-align: right;">      0.351111</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00020</td><td style="text-align: right;">  0.390193</td><td style="text-align: right;">      0.326667</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00021</td><td style="text-align: right;">  0.413296</td><td style="text-align: right;">      0.353333</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00022</td><td style="text-align: right;">  0.382925</td><td style="text-align: right;">      0.328889</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00023</td><td style="text-align: right;">  0.415112</td><td style="text-align: right;">      0.346667</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00024</td><td style="text-align: right;">  0.406027</td><td style="text-align: right;">      0.355556</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00025</td><td style="text-align: right;">  0.347354</td><td style="text-align: right;">      0.282222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00026</td><td style="text-align: right;">  0.391749</td><td style="text-align: right;">      0.322222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00027</td><td style="text-align: right;">  0.404731</td><td style="text-align: right;">      0.346667</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00028</td><td style="text-align: right;">  0.388892</td><td style="text-align: right;">      0.328889</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00029</td><td style="text-align: right;">  0.414856</td><td style="text-align: right;">      0.357778</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00030</td><td style="text-align: right;">  0.347353</td><td style="text-align: right;">      0.284444</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00031</td><td style="text-align: right;">  0.406288</td><td style="text-align: right;">      0.357778</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00032</td><td style="text-align: right;">  0.380068</td><td style="text-align: right;">      0.315556</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00033</td><td style="text-align: right;">  0.400315</td><td style="text-align: right;">      0.351111</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00034</td><td style="text-align: right;">  0.405509</td><td style="text-align: right;">      0.364444</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00035</td><td style="text-align: right;">  0.407063</td><td style="text-align: right;">      0.346667</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00036</td><td style="text-align: right;">  0.349948</td><td style="text-align: right;">      0.282222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00037</td><td style="text-align: right;">  0.405509</td><td style="text-align: right;">      0.355556</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00038</td><td style="text-align: right;">  0.385778</td><td style="text-align: right;">      0.333333</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00039</td><td style="text-align: right;">  0.405507</td><td style="text-align: right;">      0.342222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00040</td><td style="text-align: right;">  0.345019</td><td style="text-align: right;">      0.275556</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00041</td><td style="text-align: right;">  0.401611</td><td style="text-align: right;">      0.333333</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00042</td><td style="text-align: right;">  0.397462</td><td style="text-align: right;">      0.335556</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00043</td><td style="text-align: right;">  0.407326</td><td style="text-align: right;">      0.357778</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00044</td><td style="text-align: right;">  0.411477</td><td style="text-align: right;">      0.371111</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00045</td><td style="text-align: right;">  0.381883</td><td style="text-align: right;">      0.331111</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00046</td><td style="text-align: right;">  0.40421 </td><td style="text-align: right;">      0.342222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00047</td><td style="text-align: right;">  0.382144</td><td style="text-align: right;">      0.322222</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00048</td><td style="text-align: right;">  0.396163</td><td style="text-align: right;">      0.337778</td></tr>
# <tr><td>train_random_forest_SIFT_1e1b2_00049</td><td style="text-align: right;">  0.394346</td><td style="text-align: right;">      0.335556</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: no
# (train_random_forest_SIFT pid=32020) C:\arrow\cpp\src\arrow\filesystem\s3fs.cc:2598:  arrow::fs::FinalizeS3 was not called even though S3 was initialized.  This could lead to a segmentation fault at exit
# 2024-03-19 12:12:31,433	INFO tune.py:1144 -- Total run time: 1877.52 seconds (1876.53 seconds for the tuning loop).

# %%
best_config = analysis_SIFT.get_best_config(metric="accuracy", mode="max")
print("Best hyperparameters found were: ", best_config)
# Out:
# Best hyperparameters found were:  {'n_estimators': 600, 'max_depth': 300, 'min_samples_split': 2, 'min_samples_leaf': 1, 'max_features': 'log2'}

# %%
model = RandomForestClassifier(
    n_estimators=best_config['n_estimators'],
    max_depth=best_config['max_depth'],
    min_samples_split=best_config['min_samples_split'],
    min_samples_leaf=best_config['min_samples_leaf'],
    max_features=best_config['max_features'],
    )
model.fit(X_train_SIFT, y_train_SIFT)
preds = model.predict(X_test_SIFT)
test_accuracy = accuracy_score(y_test_SIFT, preds)
print(f"Test accuracy: {test_accuracy}")
# Out:
# Test accuracy: 0.34

# %% [markdown]
# ### SVM

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import AdaBoostClassifier

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_SIFT)
X_test_scaled = scaler.transform(X_test_SIFT)
svm_model = SVC(probability=True, kernel='linear')
svm_model.fit(X_train_scaled, y_train_SIFT)
y_pred = svm_model.predict(X_test_scaled)
accuracy = accuracy_score(y_test_SIFT, y_pred)
print(f"SVM Classification Accuracy: {accuracy}")
# Out:
# SVM Classification Accuracy: 0.3622222222222222

# %% [markdown]
# ## Models use raw image

# %%
def loss_and_accuracy_plot(history):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20, 5))
    
    # Plot training & validation loss values
    ax1.plot(history.history['loss'], label='Train Loss')
    ax1.plot(history.history['val_loss'], label='Validation Loss')
    ax1.set_title('Loss Function Plot')
    ax1.set_ylabel('Loss')
    ax1.set_xlabel('Epoch')
    ax1.legend(loc='upper right')
    ax1.grid(True)

    # Plot training & validation accuracy values
    ax2.plot(history.history['accuracy'], label='Train Accuracy')
    ax2.plot(history.history['val_accuracy'], label='Validation Accuracy')
    ax2.set_title('Accuracy Plot')
    ax2.set_ylabel('Accuracy')
    ax2.set_xlabel('Epoch')
    ax2.legend(loc='lower right')
    ax2.grid(True)
    plt.show()

# %% [markdown]
# ### Transfer learning

# %%
def step_decay(epoch, lr):
    drop = 0.5
    epochs_drop = 10.0
    return lr * (drop ** (epoch // epochs_drop))

# %%
def train_with_pretrained_model(X_train_t,y_train_t,X_val_t,y_val_t,base_model,filename,initial_lr):
    base_model.trainable = True
    model = Sequential([
        base_model,
        GlobalAveragePooling2D(),
        #Dense(512, activation='relu'),
        Dense(9, activation='softmax')
    ])

    lr_scheduler = LearningRateScheduler(step_decay)
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, verbose=1, mode='min')
    model_checkpoint = ModelCheckpoint(filepath=filename, monitor='val_accuracy', save_best_only=True, verbose=1)

    model.compile(optimizer=Adam(learning_rate=initial_lr), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    history = model.fit(X_train_t, y_train_t, epochs=50,validation_data=(X_val_t, y_val_t), batch_size=32, callbacks=[lr_scheduler, early_stopping, model_checkpoint])
    return model,history

# %% [markdown]
# #### VGG19

# %%
from tensorflow.keras.applications import VGG19

# %%
[VGG19_model, VGG19_history] = train_with_pretrained_model(X_train, y_train, X_val, y_val, VGG19(include_top=False, weights='imagenet', input_shape=(224,224,3)), "VGG19_t.h5", 0.0001)
loss_and_accuracy_plot(VGG19_history)
loss, accuracy = VGG19_model.evaluate(X_test, y_test)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# Epoch 1/50
# 226/226 [==============================] - 50s 183ms/step - loss: 1.8113 - accuracy: 0.3218 - val_loss: 1.3999 - val_accuracy: 0.4844
#
# Epoch 00001: val_accuracy improved from -inf to 0.48444, saving model to VGG19_t.h5
# Epoch 2/50
# 226/226 [==============================] - 38s 167ms/step - loss: 1.1232 - accuracy: 0.5988 - val_loss: 1.1750 - val_accuracy: 0.5711
#
# Epoch 00002: val_accuracy improved from 0.48444 to 0.57111, saving model to VGG19_t.h5
# Epoch 3/50
# 226/226 [==============================] - 37s 164ms/step - loss: 0.7966 - accuracy: 0.7228 - val_loss: 0.7690 - val_accuracy: 0.6978
#
# Epoch 00003: val_accuracy improved from 0.57111 to 0.69778, saving model to VGG19_t.h5
# Epoch 4/50
# 226/226 [==============================] - 38s 167ms/step - loss: 0.6125 - accuracy: 0.7804 - val_loss: 0.5918 - val_accuracy: 0.7889
#
# Epoch 00004: val_accuracy improved from 0.69778 to 0.78889, saving model to VGG19_t.h5
# Epoch 5/50
# 226/226 [==============================] - 38s 169ms/step - loss: 0.4531 - accuracy: 0.8442 - val_loss: 0.7755 - val_accuracy: 0.7511
#
# Epoch 00005: val_accuracy did not improve from 0.78889
# Epoch 6/50
# 226/226 [==============================] - 38s 168ms/step - loss: 0.4034 - accuracy: 0.8550 - val_loss: 0.6303 - val_accuracy: 0.7867
#
# Epoch 00006: val_accuracy did not improve from 0.78889
# Epoch 7/50
# 226/226 [==============================] - 38s 169ms/step - loss: 0.3083 - accuracy: 0.8936 - val_loss: 0.4935 - val_accuracy: 0.8311
#
# Epoch 00007: val_accuracy improved from 0.78889 to 0.83111, saving model to VGG19_t.h5
# Epoch 8/50
# 226/226 [==============================] - 38s 169ms/step - loss: 0.2703 - accuracy: 0.9068 - val_loss: 0.6273 - val_accuracy: 0.8133
#
# Epoch 00008: val_accuracy did not improve from 0.83111
# Epoch 9/50
# 226/226 [==============================] - 38s 169ms/step - loss: 0.2015 - accuracy: 0.9306 - val_loss: 0.7125 - val_accuracy: 0.8156
#
# Epoch 00009: val_accuracy did not improve from 0.83111
# Epoch 10/50
# 226/226 [==============================] - 38s 169ms/step - loss: 0.1737 - accuracy: 0.9395 - val_loss: 0.5673 - val_accuracy: 0.8044
#
# Epoch 00010: val_accuracy did not improve from 0.83111
# Epoch 11/50
# 226/226 [==============================] - 38s 170ms/step - loss: 0.0549 - accuracy: 0.9801 - val_loss: 0.4737 - val_accuracy: 0.8644
#
# Epoch 00011: val_accuracy improved from 0.83111 to 0.86444, saving model to VGG19_t.h5
# Epoch 12/50
# 226/226 [==============================] - 36s 160ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 0.6253 - val_accuracy: 0.8600
#
# Epoch 00012: val_accuracy did not improve from 0.86444
# Epoch 13/50
# 226/226 [==============================] - 36s 159ms/step - loss: 0.0023 - accuracy: 0.9999 - val_loss: 0.5524 - val_accuracy: 0.8600
#
# Epoch 00013: val_accuracy did not improve from 0.86444
# Epoch 14/50
# 226/226 [==============================] - 36s 161ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.5587 - val_accuracy: 0.8600
#
# Epoch 00014: val_accuracy did not improve from 0.86444
# Epoch 15/50
# 226/226 [==============================] - 37s 162ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.5640 - val_accuracy: 0.8644
#
# Epoch 00015: val_accuracy did not improve from 0.86444
# Epoch 16/50
# 226/226 [==============================] - 38s 167ms/step - loss: 9.1871e-04 - accuracy: 1.0000 - val_loss: 0.5671 - val_accuracy: 0.8644
#
# Epoch 00016: val_accuracy did not improve from 0.86444
# Epoch 17/50
# 226/226 [==============================] - 37s 162ms/step - loss: 8.7581e-04 - accuracy: 1.0000 - val_loss: 0.5683 - val_accuracy: 0.8644
#
# Epoch 00017: val_accuracy did not improve from 0.86444
# Epoch 18/50
# 226/226 [==============================] - 38s 170ms/step - loss: 8.5333e-04 - accuracy: 1.0000 - val_loss: 0.5690 - val_accuracy: 0.8644
#
# Epoch 00018: val_accuracy did not improve from 0.86444
# Epoch 19/50
# 226/226 [==============================] - 38s 168ms/step - loss: 8.4134e-04 - accuracy: 1.0000 - val_loss: 0.5694 - val_accuracy: 0.8644
#
# Epoch 00019: val_accuracy did not improve from 0.86444
# Epoch 20/50
# 226/226 [==============================] - 37s 166ms/step - loss: 8.3496e-04 - accuracy: 1.0000 - val_loss: 0.5695 - val_accuracy: 0.8644
#
# Epoch 00020: val_accuracy did not improve from 0.86444
# Epoch 21/50
# 226/226 [==============================] - 37s 165ms/step - loss: 8.3159e-04 - accuracy: 1.0000 - val_loss: 0.5696 - val_accuracy: 0.8644
#
# Epoch 00021: val_accuracy did not improve from 0.86444
# Epoch 00021: early stopping
# 15/15 [==============================] - 1s 44ms/step - loss: 0.7300 - accuracy: 0.8711
# Test loss: 0.7300341725349426, Test accuracy: 0.8711110949516296

# %% [markdown]
# #### DenseNet121

# %%
del VGG19_model
del VGG19_history

# %%
from tensorflow.keras.applications import DenseNet121

# %%
[DenseNet121_model, DenseNet121_history] = train_with_pretrained_model(X_train, y_train, X_val, y_val, DenseNet121(include_top=False, weights='imagenet', input_shape=(224,224,3)), "DenseNet121_t.h5", 0.001)
loss_and_accuracy_plot(DenseNet121_history)
loss, accuracy = DenseNet121_model.evaluate(X_test, y_test)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# Epoch 1/50
# 226/226 [==============================] - 41s 144ms/step - loss: 0.8383 - accuracy: 0.7143 - val_loss: 2.7097 - val_accuracy: 0.3667
#
# Epoch 00001: val_accuracy improved from -inf to 0.36667, saving model to DenseNet121_t.h5
# Epoch 2/50
# 226/226 [==============================] - 31s 135ms/step - loss: 0.4626 - accuracy: 0.8428 - val_loss: 2.6516 - val_accuracy: 0.3489
#
# Epoch 00002: val_accuracy did not improve from 0.36667
# Epoch 3/50
# 226/226 [==============================] - 30s 135ms/step - loss: 0.3324 - accuracy: 0.8844 - val_loss: 1.2657 - val_accuracy: 0.6178
#
# Epoch 00003: val_accuracy improved from 0.36667 to 0.61778, saving model to DenseNet121_t.h5
# Epoch 4/50
# 226/226 [==============================] - 31s 134ms/step - loss: 0.2853 - accuracy: 0.9018 - val_loss: 6.0409 - val_accuracy: 0.2622
#
# Epoch 00004: val_accuracy did not improve from 0.61778
# Epoch 5/50
# 226/226 [==============================] - 31s 135ms/step - loss: 0.1990 - accuracy: 0.9303 - val_loss: 2.6519 - val_accuracy: 0.4533
#
# Epoch 00005: val_accuracy did not improve from 0.61778
# Epoch 6/50
# 226/226 [==============================] - 30s 135ms/step - loss: 0.1904 - accuracy: 0.9324 - val_loss: 2.7524 - val_accuracy: 0.5222
#
# Epoch 00006: val_accuracy did not improve from 0.61778
# Epoch 7/50
# 226/226 [==============================] - 31s 136ms/step - loss: 0.1442 - accuracy: 0.9496 - val_loss: 2.5342 - val_accuracy: 0.5111
#
# Epoch 00007: val_accuracy did not improve from 0.61778
# Epoch 8/50
# 226/226 [==============================] - 31s 137ms/step - loss: 0.1688 - accuracy: 0.9453 - val_loss: 1.7960 - val_accuracy: 0.5622
#
# Epoch 00008: val_accuracy did not improve from 0.61778
# Epoch 9/50
# 226/226 [==============================] - 31s 136ms/step - loss: 0.1218 - accuracy: 0.9554 - val_loss: 2.2142 - val_accuracy: 0.5667
#
# Epoch 00009: val_accuracy did not improve from 0.61778
# Epoch 10/50
# 226/226 [==============================] - 30s 135ms/step - loss: 0.1065 - accuracy: 0.9629 - val_loss: 5.6264 - val_accuracy: 0.2578
#
# Epoch 00010: val_accuracy did not improve from 0.61778
# Epoch 11/50
# 226/226 [==============================] - 30s 133ms/step - loss: 0.0330 - accuracy: 0.9903 - val_loss: 0.3447 - val_accuracy: 0.8978
#
# Epoch 00011: val_accuracy improved from 0.61778 to 0.89778, saving model to DenseNet121_t.h5
# Epoch 12/50
# 226/226 [==============================] - 30s 129ms/step - loss: 0.0070 - accuracy: 0.9990 - val_loss: 0.2923 - val_accuracy: 0.9044
#
# Epoch 00012: val_accuracy improved from 0.89778 to 0.90444, saving model to DenseNet121_t.h5
# Epoch 13/50
# 226/226 [==============================] - 29s 128ms/step - loss: 0.0038 - accuracy: 0.9999 - val_loss: 0.2807 - val_accuracy: 0.9089
#
# Epoch 00013: val_accuracy improved from 0.90444 to 0.90889, saving model to DenseNet121_t.h5
# Epoch 14/50
# 226/226 [==============================] - 30s 131ms/step - loss: 0.0034 - accuracy: 0.9996 - val_loss: 0.2724 - val_accuracy: 0.9067
#
# Epoch 00014: val_accuracy did not improve from 0.90889
# Epoch 15/50
# 226/226 [==============================] - 30s 133ms/step - loss: 0.0029 - accuracy: 0.9999 - val_loss: 0.2832 - val_accuracy: 0.9111
#
# Epoch 00015: val_accuracy improved from 0.90889 to 0.91111, saving model to DenseNet121_t.h5
# Epoch 16/50
# 226/226 [==============================] - 31s 136ms/step - loss: 0.0030 - accuracy: 0.9997 - val_loss: 0.2760 - val_accuracy: 0.9111
#
# Epoch 00016: val_accuracy did not improve from 0.91111
# Epoch 17/50
# 226/226 [==============================] - 31s 135ms/step - loss: 0.0028 - accuracy: 0.9999 - val_loss: 0.2781 - val_accuracy: 0.9111
#
# Epoch 00017: val_accuracy did not improve from 0.91111
# Epoch 18/50
# 226/226 [==============================] - 31s 137ms/step - loss: 0.0030 - accuracy: 0.9999 - val_loss: 0.2774 - val_accuracy: 0.9133
#
# Epoch 00018: val_accuracy improved from 0.91111 to 0.91333, saving model to DenseNet121_t.h5
# Epoch 19/50
# 226/226 [==============================] - 31s 137ms/step - loss: 0.0027 - accuracy: 0.9999 - val_loss: 0.2763 - val_accuracy: 0.9089
#
# Epoch 00019: val_accuracy did not improve from 0.91333
# Epoch 20/50
# 226/226 [==============================] - 31s 137ms/step - loss: 0.0031 - accuracy: 0.9999 - val_loss: 0.2759 - val_accuracy: 0.9089
#
# Epoch 00020: val_accuracy did not improve from 0.91333
# Epoch 21/50
# 226/226 [==============================] - 31s 136ms/step - loss: 0.0026 - accuracy: 0.9999 - val_loss: 0.2791 - val_accuracy: 0.9089
#
# Epoch 00021: val_accuracy did not improve from 0.91333
# Epoch 22/50
# 226/226 [==============================] - 31s 136ms/step - loss: 0.0029 - accuracy: 0.9999 - val_loss: 0.2775 - val_accuracy: 0.9089
#
# Epoch 00022: val_accuracy did not improve from 0.91333
# Epoch 23/50
# 226/226 [==============================] - 31s 137ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.2768 - val_accuracy: 0.9089
#
# Epoch 00023: val_accuracy did not improve from 0.91333
# Epoch 24/50
# 226/226 [==============================] - 31s 136ms/step - loss: 0.0028 - accuracy: 0.9999 - val_loss: 0.2775 - val_accuracy: 0.9111
#
# Epoch 00024: val_accuracy did not improve from 0.91333
# Epoch 00024: early stopping
# 15/15 [==============================] - 1s 33ms/step - loss: 0.2182 - accuracy: 0.9444
# Test loss: 0.21821220219135284, Test accuracy: 0.9444444179534912

# %%
del DenseNet121_model
del DenseNet121_history

# %%
import gc
gc.collect()
# Out:
# 59235

# %% [markdown]
# #### InceptionV3

# %%
from tensorflow.keras.applications import InceptionV3

# %%
[InceptionV3_model, InceptionV3_history] = train_with_pretrained_model(X_train, y_train, X_val, y_val, InceptionV3(include_top=False, weights='imagenet', input_shape=(224,224,3)), "InceptionV3_t.h5", 0.001)
loss_and_accuracy_plot(InceptionV3_history)
loss, accuracy = InceptionV3_model.evaluate(X_test, y_test)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# Epoch 1/50
# 226/226 [==============================] - 27s 92ms/step - loss: 0.9351 - accuracy: 0.6812 - val_loss: 2.1010 - val_accuracy: 0.3489
#
# Epoch 00001: val_accuracy improved from -inf to 0.34889, saving model to InceptionV3_t.h5
# Epoch 2/50
# 226/226 [==============================] - 19s 85ms/step - loss: 0.5368 - accuracy: 0.8142 - val_loss: 1.2583 - val_accuracy: 0.5978
#
# Epoch 00002: val_accuracy improved from 0.34889 to 0.59778, saving model to InceptionV3_t.h5
# Epoch 3/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.4079 - accuracy: 0.8590 - val_loss: 0.9856 - val_accuracy: 0.6933
#
# Epoch 00003: val_accuracy improved from 0.59778 to 0.69333, saving model to InceptionV3_t.h5
# Epoch 4/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.3168 - accuracy: 0.8866 - val_loss: 1.3276 - val_accuracy: 0.6511
#
# Epoch 00004: val_accuracy did not improve from 0.69333
# Epoch 5/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.2574 - accuracy: 0.9122 - val_loss: 1.2307 - val_accuracy: 0.6578
#
# Epoch 00005: val_accuracy did not improve from 0.69333
# Epoch 6/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.2103 - accuracy: 0.9303 - val_loss: 0.7837 - val_accuracy: 0.7822
#
# Epoch 00006: val_accuracy improved from 0.69333 to 0.78222, saving model to InceptionV3_t.h5
# Epoch 7/50
# 226/226 [==============================] - 19s 86ms/step - loss: 0.1771 - accuracy: 0.9382 - val_loss: 2.9905 - val_accuracy: 0.4400
#
# Epoch 00007: val_accuracy did not improve from 0.78222
# Epoch 8/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.1711 - accuracy: 0.9423 - val_loss: 1.6125 - val_accuracy: 0.6111
#
# Epoch 00008: val_accuracy did not improve from 0.78222
# Epoch 9/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.1109 - accuracy: 0.9618 - val_loss: 2.0920 - val_accuracy: 0.6000
#
# Epoch 00009: val_accuracy did not improve from 0.78222
# Epoch 10/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.1285 - accuracy: 0.9560 - val_loss: 1.5465 - val_accuracy: 0.6689
#
# Epoch 00010: val_accuracy did not improve from 0.78222
# Epoch 11/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0340 - accuracy: 0.9886 - val_loss: 0.6148 - val_accuracy: 0.8467
#
# Epoch 00011: val_accuracy improved from 0.78222 to 0.84667, saving model to InceptionV3_t.h5
# Epoch 12/50
# 226/226 [==============================] - 19s 85ms/step - loss: 0.0122 - accuracy: 0.9970 - val_loss: 0.4517 - val_accuracy: 0.8644
#
# Epoch 00012: val_accuracy improved from 0.84667 to 0.86444, saving model to InceptionV3_t.h5
# Epoch 13/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 0.3681 - val_accuracy: 0.8867
#
# Epoch 00013: val_accuracy improved from 0.86444 to 0.88667, saving model to InceptionV3_t.h5
# Epoch 14/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0034 - accuracy: 0.9997 - val_loss: 0.3781 - val_accuracy: 0.8844
#
# Epoch 00014: val_accuracy did not improve from 0.88667
# Epoch 15/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.3732 - val_accuracy: 0.8844
#
# Epoch 00015: val_accuracy did not improve from 0.88667
# Epoch 16/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0030 - accuracy: 0.9999 - val_loss: 0.3738 - val_accuracy: 0.8822
#
# Epoch 00016: val_accuracy did not improve from 0.88667
# Epoch 17/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0033 - accuracy: 0.9997 - val_loss: 0.3749 - val_accuracy: 0.8822
#
# Epoch 00017: val_accuracy did not improve from 0.88667
# Epoch 18/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0030 - accuracy: 0.9999 - val_loss: 0.3742 - val_accuracy: 0.8867
#
# Epoch 00018: val_accuracy did not improve from 0.88667
# Epoch 19/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.3734 - val_accuracy: 0.8889
#
# Epoch 00019: val_accuracy improved from 0.88667 to 0.88889, saving model to InceptionV3_t.h5
# Epoch 20/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0028 - accuracy: 0.9999 - val_loss: 0.3760 - val_accuracy: 0.8867
#
# Epoch 00020: val_accuracy did not improve from 0.88889
# Epoch 21/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0034 - accuracy: 0.9994 - val_loss: 0.3745 - val_accuracy: 0.8867
#
# Epoch 00021: val_accuracy did not improve from 0.88889
# Epoch 22/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3768 - val_accuracy: 0.8889
#
# Epoch 00022: val_accuracy did not improve from 0.88889
# Epoch 23/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.3771 - val_accuracy: 0.8867
#
# Epoch 00023: val_accuracy did not improve from 0.88889
# Epoch 00023: early stopping
# 15/15 [==============================] - 0s 24ms/step - loss: 0.3143 - accuracy: 0.9156
# Test loss: 0.31430235505104065, Test accuracy: 0.9155555367469788

# %%
del InceptionV3_model
del InceptionV3_history
gc.collect()
# Out:
# 44005

# %% [markdown]
# #### MobileNet

# %%
from tensorflow.keras.applications import MobileNet

# %%
[MobileNet_model, MobileNet_history] = train_with_pretrained_model(X_train, y_train, X_val, y_val, MobileNet(include_top=False, weights='imagenet', input_shape=(224,224,3)), "MobileNet_t.h5", 0.001)
loss_and_accuracy_plot(MobileNet_history)
loss, accuracy = MobileNet_model.evaluate(X_test, y_test)
print(f'Test loss: {loss}, Test accuracy: {accuracy}')
# Out:
# Epoch 1/50
# 226/226 [==============================] - 21s 86ms/step - loss: 0.7349 - accuracy: 0.7593 - val_loss: 1.7053 - val_accuracy: 0.6267
#
# Epoch 00001: val_accuracy improved from -inf to 0.62667, saving model to MobileNet_t.h5
# Epoch 2/50
# 226/226 [==============================] - 19s 83ms/step - loss: 0.2954 - accuracy: 0.8990 - val_loss: 1.6437 - val_accuracy: 0.6200
#
# Epoch 00002: val_accuracy did not improve from 0.62667
# Epoch 3/50
# 226/226 [==============================] - 19s 85ms/step - loss: 0.2247 - accuracy: 0.9208 - val_loss: 1.2028 - val_accuracy: 0.6689
#
# Epoch 00003: val_accuracy improved from 0.62667 to 0.66889, saving model to MobileNet_t.h5
# Epoch 4/50
# 226/226 [==============================] - 20s 90ms/step - loss: 0.1696 - accuracy: 0.9393 - val_loss: 0.7757 - val_accuracy: 0.7933
#
# Epoch 00004: val_accuracy improved from 0.66889 to 0.79333, saving model to MobileNet_t.h5
# Epoch 5/50
# 226/226 [==============================] - 20s 88ms/step - loss: 0.1697 - accuracy: 0.9438 - val_loss: 0.8673 - val_accuracy: 0.7667
#
# Epoch 00005: val_accuracy did not improve from 0.79333
# Epoch 6/50
# 226/226 [==============================] - 20s 88ms/step - loss: 0.1188 - accuracy: 0.9583 - val_loss: 1.1124 - val_accuracy: 0.7533
#
# Epoch 00006: val_accuracy did not improve from 0.79333
# Epoch 7/50
# 226/226 [==============================] - 20s 88ms/step - loss: 0.0988 - accuracy: 0.9670 - val_loss: 1.4117 - val_accuracy: 0.7244
#
# Epoch 00007: val_accuracy did not improve from 0.79333
# Epoch 8/50
# 226/226 [==============================] - 20s 88ms/step - loss: 0.0962 - accuracy: 0.9659 - val_loss: 1.8365 - val_accuracy: 0.6889
#
# Epoch 00008: val_accuracy did not improve from 0.79333
# Epoch 9/50
# 226/226 [==============================] - 20s 89ms/step - loss: 0.1175 - accuracy: 0.9568 - val_loss: 0.8866 - val_accuracy: 0.8178
#
# Epoch 00009: val_accuracy improved from 0.79333 to 0.81778, saving model to MobileNet_t.h5
# Epoch 10/50
# 226/226 [==============================] - 20s 88ms/step - loss: 0.0789 - accuracy: 0.9751 - val_loss: 1.1697 - val_accuracy: 0.7556
#
# Epoch 00010: val_accuracy did not improve from 0.81778
# Epoch 11/50
# 226/226 [==============================] - 19s 86ms/step - loss: 0.0236 - accuracy: 0.9927 - val_loss: 0.4444 - val_accuracy: 0.8889
#
# Epoch 00011: val_accuracy improved from 0.81778 to 0.88889, saving model to MobileNet_t.h5
# Epoch 12/50
# 226/226 [==============================] - 20s 88ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.3369 - val_accuracy: 0.8911
#
# Epoch 00012: val_accuracy improved from 0.88889 to 0.89111, saving model to MobileNet_t.h5
# Epoch 13/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.3094 - val_accuracy: 0.9089
#
# Epoch 00013: val_accuracy improved from 0.89111 to 0.90889, saving model to MobileNet_t.h5
# Epoch 14/50
# 226/226 [==============================] - 20s 88ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 0.3119 - val_accuracy: 0.9000
#
# Epoch 00014: val_accuracy did not improve from 0.90889
# Epoch 15/50
# 226/226 [==============================] - 20s 88ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.3120 - val_accuracy: 0.9000
#
# Epoch 00015: val_accuracy did not improve from 0.90889
# Epoch 16/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0016 - accuracy: 0.9996 - val_loss: 0.3149 - val_accuracy: 0.9000
#
# Epoch 00016: val_accuracy did not improve from 0.90889
# Epoch 17/50
# 226/226 [==============================] - 19s 83ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.3141 - val_accuracy: 0.9000
#
# Epoch 00017: val_accuracy did not improve from 0.90889
# Epoch 18/50
# 226/226 [==============================] - 20s 88ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.3154 - val_accuracy: 0.9000
#
# Epoch 00018: val_accuracy did not improve from 0.90889
# Epoch 19/50
# 226/226 [==============================] - 19s 85ms/step - loss: 0.0016 - accuracy: 0.9999 - val_loss: 0.3154 - val_accuracy: 0.9000
#
# Epoch 00019: val_accuracy did not improve from 0.90889
# Epoch 20/50
# 226/226 [==============================] - 19s 85ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 0.3128 - val_accuracy: 0.9000
#
# Epoch 00020: val_accuracy did not improve from 0.90889
# Epoch 21/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0021 - accuracy: 0.9999 - val_loss: 0.3124 - val_accuracy: 0.9000
#
# Epoch 00021: val_accuracy did not improve from 0.90889
# Epoch 22/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.3119 - val_accuracy: 0.9000
#
# Epoch 00022: val_accuracy did not improve from 0.90889
# Epoch 23/50
# 226/226 [==============================] - 20s 87ms/step - loss: 0.0015 - accuracy: 0.9999 - val_loss: 0.3104 - val_accuracy: 0.8978
#
# Epoch 00023: val_accuracy did not improve from 0.90889
# Epoch 00023: early stopping
# 15/15 [==============================] - 0s 12ms/step - loss: 0.3510 - accuracy: 0.9089
# Test loss: 0.35101181268692017, Test accuracy: 0.9088888764381409

# %%
del MobileNet_model
del MobileNet_history
gc.collect()
# Out:
# 20784

# %% [markdown]
# ### Ensemble (soft voting)

# %%
def voting(list_of_models, X_test_t, y_test_t):
    true = 0
    false = 0
    for i in range(len(X_test_t)):
        probs = []
        for model in list_of_models:
            img = np.expand_dims(X_test_t[i], axis=0)
            res = model.predict(img)
            probs.append(res)
        average_probs = np.mean(np.stack(probs), axis=0)
        decision = np.argmax(average_probs, axis=1)
        #print(decision)
        if decision == y_test_t[i]:
            true += 1
        else:
            false += 1      
    print("Correct predication:" ,true)
    print("Incorrect predication:" ,false)
    return true / (true + false)

# %%
def voting_demo(list_of_models, img, models_name):
    num_classes = len(index_to_label)  # Assuming index_to_label's keys are 0-indexed class IDs
    # Initialize an array to store probabilities from each model for each class
    probs = np.zeros((len(list_of_models), num_classes))
    
    for i, model in enumerate(list_of_models):
        res = model.predict(img)
        # Assuming the result is softmax probabilities, take the mean if necessary
        if res.ndim > 2:
            res = np.mean(res, axis=0)
        probs[i] = res
    
    # Calculate the average probabilities across all models
    average_probs = np.mean(probs, axis=0)
    decision = np.argmax(average_probs)
    
    colors = ['skyblue', 'lightgreen', 'salmon', 'orange']
    
    plt.figure(figsize=(10, 5))
    
    # Plot the input image
    plt.subplot(1, 2, 1)
    plt.imshow(img[0])
    plt.title("Input Image")
    
    # Plot the average probabilities with contributions from each model
    plt.subplot(1, 2, 2)
    bottom = np.zeros(num_classes)
    for i in range(len(list_of_models)):
        plt.bar(range(num_classes), probs[i], bottom=bottom, color=colors[i], edgecolor='white', label=models_name[i])
        bottom += probs[i]
    
    plt.title("Probabilities with Each Model Contributions")
    plt.xlabel("Class")
    plt.ylabel("Probability")
    plt.xticks(range(num_classes), [index_to_label[i] for i in range(num_classes)], rotation='vertical')
    plt.legend()
    
    plt.tight_layout()
    plt.show()

    print("Average probabilities:", average_probs)
    print("Predicted class:", index_to_label[decision])

# %%
VGG19_model = load_model("VGG19_t.h5")
DenseNet121_model = load_model("DenseNet121_t.h5")
InceptionV3_model = load_model("InceptionV3_t.h5")
MobileNet_model = load_model("MobileNet_t.h5")

# %%
model_list = [VGG19_model,DenseNet121_model,InceptionV3_model,MobileNet_model]

# %%
model_name = ["VGG19","DenseNet121","InceptionV3","MobileNet"]

# %%
voting_demo(model_list, X_test[13].reshape(1, 224, 224, 3), model_name)
# Out:
# Average probabilities: [4.51782981e-05 9.99399886e-01 2.78317269e-07 1.52093075e-04
#  5.11950199e-05 6.33089152e-06 3.34273447e-04 1.29053368e-06
#  9.48870641e-06]
# Predicted class: Food Organics

# %%
voting_demo(model_list, X_test[386].reshape(1, 224, 224, 3), model_name)
# Out:
# Average probabilities: [7.42437246e-05 1.63538738e-04 2.44029522e-03 2.58626489e-06
#  3.39649019e-01 5.69901928e-04 4.61510790e-04 6.56624250e-01
#  1.46531761e-05]
# Predicted class: Textile Trash

# %%
print(f"Test Accuracy: {voting([VGG19_model,DenseNet121_model,InceptionV3_model,MobileNet_model],X_test, y_test)}")
# Out:
# Correct predication: 427
# Incorrect predication: 23
# Test Accuracy: 0.9488888888888889

# %%
def find_combinations(input_list, combination_lengths):
    from itertools import combinations
    
    all_combinations = []
    for length in combination_lengths:
        all_combinations.extend(list(combinations(input_list, length)))
    
    return all_combinations

# %%
input_list = [0, 1, 2, 3]
combination_lengths = [2]

resulting_combinations = find_combinations(input_list, combination_lengths)

# %%
for m in model_list:
    print(f"Test Accuracy: {voting([m],X_test, y_test)}")
# Out:
# Correct predication: 383
# Incorrect predication: 67
# Test Accuracy: 0.8511111111111112
# Correct predication: 426
# Incorrect predication: 24
# Test Accuracy: 0.9466666666666667
# Correct predication: 415
# Incorrect predication: 35
# Test Accuracy: 0.9222222222222223
# Correct predication: 410
# Incorrect predication: 40
# Test Accuracy: 0.9111111111111111

# %%
for (x,y) in resulting_combinations:
    print(f"Test Accuracy: {voting([model_list[x],model_list[y]],X_test, y_test)}")
# Out:
# Correct predication: 416
# Incorrect predication: 34
# Test Accuracy: 0.9244444444444444
# Correct predication: 412
# Incorrect predication: 38
# Test Accuracy: 0.9155555555555556
# Correct predication: 412
# Incorrect predication: 38
# Test Accuracy: 0.9155555555555556
# Correct predication: 425
# Incorrect predication: 25
# Test Accuracy: 0.9444444444444444
# Correct predication: 420
# Incorrect predication: 30
# Test Accuracy: 0.9333333333333333
# Correct predication: 418
# Incorrect predication: 32
# Test Accuracy: 0.9288888888888889

# %%
combination_lengths = [3]
resulting_combinations = find_combinations(input_list, combination_lengths)

# %%
for (x,y,z) in resulting_combinations:
    print(f"Test Accuracy: {voting([model_list[x],model_list[y],model_list[z]],X_test, y_test)}")
# Out:
# Correct predication: 423
# Incorrect predication: 27
# Test Accuracy: 0.94
# Correct predication: 423
# Incorrect predication: 27
# Test Accuracy: 0.94
# Correct predication: 420
# Incorrect predication: 30
# Test Accuracy: 0.9333333333333333
# Correct predication: 423
# Incorrect predication: 27
# Test Accuracy: 0.94

# %% [markdown]
# ## Vision Transformer

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import models, transforms
from torch.utils.data import TensorDataset, DataLoader
import timm
from transformers import ViTFeatureExtractor, TFAutoModelForImageClassification, ViTForImageClassification
from transformers import AutoConfig
from torchvision.transforms import Compose, Resize, CenterCrop, ToTensor, Normalize
from transformers import AutoImageProcessor, ViTModel
from torch.utils.data import Dataset

# %%
import torch
print(torch.__version__) 
print(torch.cuda.is_available())
# Out:
# 2.2.1
# True

# %%
model_name = 'google/vit-base-patch16-224'

# %%
image_processor = AutoImageProcessor.from_pretrained(model_name)
model = ViTForImageClassification.from_pretrained(model_name)

# %%
class CustomImageDataset(Dataset):
    def __init__(self, images, labels, feature_extractor):
        self.images = images
        self.labels = labels
        self.feature_extractor = feature_extractor

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        image = self.images[idx]
        image = self.feature_extractor(images=image, return_tensors="pt").pixel_values.squeeze()
        label = self.labels[idx]
        label = torch.tensor(label, dtype=torch.long)  # Convert label to a tensor
        return image, label

# %%
def np_to_list(nparray):
    li = []
    for i in range(nparray.shape[0]):
        img = Image.fromarray(nparray[i].astype('uint8'), 'RGB')
        li.append(img)
    return li

# %%
X_train_raw = np_to_list(X_train)
X_val_raw = np_to_list(X_val)
X_test_raw = np_to_list(X_test)

# %%
y_train = y_train.tolist()
y_val = y_val.tolist()
y_test = y_test.tolist()

# %%
batch_size = 32

train_dataset = CustomImageDataset(X_train_raw, y_train, image_processor)
val_dataset = CustomImageDataset(X_val_raw, y_val, image_processor)
test_dataset = CustomImageDataset(X_test_raw, y_test, image_processor)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

optimizer = torch.optim.Adam(model.parameters(), lr=5e-5)
criterion = torch.nn.CrossEntropyLoss() 
num_epochs = 10

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    correct_predictions = 0
    total_predictions = 0
    
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        
        outputs = model(images)
        logits = outputs.logits
        loss = criterion(logits, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        
        _, predicted = torch.max(logits.data, 1)
        total_predictions += labels.size(0)
        correct_predictions += (predicted == labels).sum().item()
        
    epoch_loss = running_loss / len(train_loader)
    epoch_accuracy = correct_predictions / total_predictions * 100

    model.eval()  # Set the model to evaluation mode
    val_running_loss = 0.0
    val_correct_predictions = 0
    val_total_predictions = 0
    
    with torch.no_grad():  # Disable gradient calculation
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            
            outputs = model(images)
            logits = outputs.logits
            loss = criterion(logits, labels)
            
            val_running_loss += loss.item()
            
            _, predicted = torch.max(logits.data, 1)
            val_total_predictions += labels.size(0)
            val_correct_predictions += (predicted == labels).sum().item()
    
    val_loss = val_running_loss / len(val_loader)
    val_accuracy = val_correct_predictions / val_total_predictions * 100
    
    print(f"Epoch {epoch+1}, "
          f"Train Loss: {epoch_loss:.4f}, Train Accuracy: {epoch_accuracy:.2f}%, "
          f"Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.2f}%")
# Out:
# Epoch 1, Train Loss: 0.1292, Train Accuracy: 95.85%, Val Loss: 0.3213, Val Accuracy: 90.00%
# Epoch 2, Train Loss: 0.0359, Train Accuracy: 98.98%, Val Loss: 0.3067, Val Accuracy: 91.56%
# Epoch 3, Train Loss: 0.0123, Train Accuracy: 99.67%, Val Loss: 0.2642, Val Accuracy: 94.00%
# Epoch 4, Train Loss: 0.0015, Train Accuracy: 99.99%, Val Loss: 0.2025, Val Accuracy: 95.11%
# Epoch 5, Train Loss: 0.0004, Train Accuracy: 100.00%, Val Loss: 0.2023, Val Accuracy: 95.56%
# Epoch 6, Train Loss: 0.0003, Train Accuracy: 100.00%, Val Loss: 0.2072, Val Accuracy: 95.33%
# Epoch 7, Train Loss: 0.0002, Train Accuracy: 100.00%, Val Loss: 0.2119, Val Accuracy: 95.33%
# Epoch 8, Train Loss: 0.0002, Train Accuracy: 100.00%, Val Loss: 0.2143, Val Accuracy: 95.33%
# Epoch 9, Train Loss: 0.0001, Train Accuracy: 100.00%, Val Loss: 0.2193, Val Accuracy: 95.33%
# Epoch 10, Train Loss: 0.0001, Train Accuracy: 100.00%, Val Loss: 0.2226, Val Accuracy: 95.33%

# %%
correct = 0
total = 0
model.eval()

with torch.no_grad(): 
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.logits, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of test set: {100 * correct / total}%')
# Out:
# Accuracy of test set: 95.55555555555556%
